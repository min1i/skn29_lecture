# %% [markdown]
# # [머신러닝] 다항회귀 실습
#
# - 데이터는 선택
# - 전처리 (결측치, 이상치, 표준화)
#
# 1. 모델 선택
# 2. 모델 학습
# 3. 모델

# %%
from glob import glob
import pandas as pd

df = pd.read_csv(glob(path+'/*.csv')[0])
df['Outcome'].value_counts()

# 분류 문제, 대표적인 불균형, classification_report ??

# %%
# 이상치
# x = df
# y = df
df[Pregnancies]
